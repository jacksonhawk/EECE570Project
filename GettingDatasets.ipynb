# %% [markdown]
# <a href="https://colab.research.google.com/github/jacksonhawk/EECE570Project/blob/main/GettingDatasets.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !git clone https://github.com/ultralytics/yolov5  # clone
# %cd yolov5
# !pip install -r requirements.txt  # install
# Out:
# Cloning into 'yolov5'...
# remote: Enumerating objects: 15368, done.
# remote: Counting objects: 100% (13/13), done.
# remote: Compressing objects: 100% (13/13), done.
# remote: Total 15368 (delta 1), reused 6 (delta 0), pack-reused 15355
# Receiving objects: 100% (15368/15368), 14.36 MiB | 24.55 MiB/s, done.
# Resolving deltas: 100% (10504/10504), done.
# /content/yolov5/yolov5
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
# %cd /content/yolov5
# !python train.py --img 640 --epochs 3 --data coco128.yaml --weights yolov5s.pt
# Out:
# /content/yolov5
# 2023-04-07 23:09:27.031713: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-04-07 23:09:28.231452: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# ...

# %%
# !zip -r /content/coco128.zip /content/datasets/coco128
# Out:
#   adding: content/datasets/coco128/ (stored 0%)
#   adding: content/datasets/coco128/labels/ (stored 0%)
#   adding: content/datasets/coco128/labels/train2017/ (stored 0%)
#   adding: content/datasets/coco128/labels/train2017/000000000042.txt (deflated 9%)
#   adding: content/datasets/coco128/labels/train2017/000000000192.txt (deflated 45%)
#   adding: content/datasets/coco128/labels/train2017/000000000382.txt (deflated 38%)
#   adding: content/datasets/coco128/labels/train2017/000000000312.txt (deflated 49%)
#   adding: content/datasets/coco128/labels/train2017/000000000599.txt (deflated 47%)
#   adding: content/datasets/coco128/labels/train2017/000000000650.txt (deflated 29%)
#   adding: content/datasets/coco128/labels/train2017/000000000590.txt (deflated 25%)
#   adding: content/datasets/coco128/labels/train2017/000000000257.txt (deflated 59%)
#   adding: content/datasets/coco128/labels/train2017/000000000584.txt (deflated 55%)
# ...

# %%
# %cd /content/yolov5
# !python train.py --img 640 --epochs 3 --data VOC.yaml --weights yolov5s.pt
# Out:
# /content/yolov5
# 2023-04-07 23:12:19.579597: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-04-07 23:12:20.769118: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# ...

# %%
# !zip -r /content/VOCimagesTest2007.zip /content/datasets/VOC/images/test2007
# !zip -r /content/VOClabelsTest2007.zip /content/datasets/VOC/labels/test2007
# Out:
# Streaming output truncated to the last 5000 lines.
#   adding: content/datasets/VOC/images/test2007/004861.jpg (deflated 0%)
#   adding: content/datasets/VOC/images/test2007/000076.jpg (deflated 0%)
#   adding: content/datasets/VOC/images/test2007/009957.jpg (deflated 0%)
#   adding: content/datasets/VOC/images/test2007/007218.jpg (deflated 0%)
#   adding: content/datasets/VOC/images/test2007/007186.jpg (deflated 0%)
#   adding: content/datasets/VOC/images/test2007/000861.jpg (deflated 4%)
#   adding: content/datasets/VOC/images/test2007/000556.jpg (deflated 0%)
#   adding: content/datasets/VOC/images/test2007/002316.jpg (deflated 0%)
#   adding: content/datasets/VOC/images/test2007/001086.jpg (deflated 0%)
#   adding: content/datasets/VOC/images/test2007/003892.jpg (deflated 0%)
#   adding: content/datasets/VOC/images/test2007/003725.jpg (deflated 0%)
#   adding: content/datasets/VOC/images/test2007/002562.jpg (deflated 0%)
# ...

# %%
# %cd /content/yolov5
# !python train.py --img 640 --epochs 3 --data coco.yaml --weights yolov5s.pt
# Out:
# /content/yolov5
# 2023-04-07 23:15:47.527707: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-04-07 23:15:48.738469: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# ...

# %%
# !zip -r /content/COCOannotations.zip /content/datasets/coco/annotations
# !zip -r /content/COCOimagesVal2017.zip /content/datasets/coco/images/val2017
# !zip -r /content/COCOlabelsVal2017.zip /content/datasets/coco/labels/val2017
# Out:
# Streaming output truncated to the last 5000 lines.
#   adding: content/datasets/coco/images/val2017/000000136600.jpg (deflated 0%)
#   adding: content/datasets/coco/images/val2017/000000412887.jpg (deflated 0%)
#   adding: content/datasets/coco/images/val2017/000000288685.jpg (deflated 0%)
#   adding: content/datasets/coco/images/val2017/000000485130.jpg (deflated 0%)
#   adding: content/datasets/coco/images/val2017/000000482970.jpg (deflated 0%)
#   adding: content/datasets/coco/images/val2017/000000124636.jpg (deflated 0%)
#   adding: content/datasets/coco/images/val2017/000000481386.jpg (deflated 0%)
#   adding: content/datasets/coco/images/val2017/000000485027.jpg (deflated 5%)
#   adding: content/datasets/coco/images/val2017/000000057027.jpg (deflated 3%)
#   adding: content/datasets/coco/images/val2017/000000186637.jpg (deflated 0%)
#   adding: content/datasets/coco/images/val2017/000000144114.jpg (deflated 0%)
# ...
